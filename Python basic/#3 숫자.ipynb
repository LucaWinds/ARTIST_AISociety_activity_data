# %% [markdown]
# # **숫자**
# #### 정수형(integer) or 실수형(floating point)

# %%
#절대 다른 자료를 연산하지 않는다.
a = 2
b = 3

# 더하고
print(a+b)
# 빼고
print(a-b)
# 곱하고
print(a*b)
# 나누고
print(a/b)
# 나머지 구하고
print(a%b)
# 몫 구하고
print(a//b)
# 제곱하고
print(a**b)
# Out:
# 5
# -1
# 6
# 0.6666666666666666
# 2
# 0
# 8
